# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
data = np.zeros((200,3))
x1 = np.random.normal(1,0.3,100)
y1 = np.random.normal(1,0.3,100)
x2 = np.random.normal(-1,0.3,100)
y2 = np.random.normal(-1,0.3,100) 

for i in range(100):
    data[i,0] = x1[i]
    data[i,1] = y1[i]
    data[i,2] = 1
    
for i in range(100):
    data[i+100,0] = x2[i]
    data[i+100,1] = y2[i]
    data[i+100,2] = -1
data
# Out:
# array([[ 1.34413359,  0.91671421,  1.        ],
#        [ 0.28856604,  1.20870428,  1.        ],
#        [ 1.1709399 ,  0.93797273,  1.        ],
#        [ 1.07897556,  0.55575657,  1.        ],
#        [ 1.04829446,  0.65623618,  1.        ],
#        [ 0.86539055,  0.80588179,  1.        ],
#        [ 1.15972644,  1.2032667 ,  1.        ],
#        [ 0.84955269,  0.65656662,  1.        ],
#        [ 0.11224037,  1.29550228,  1.        ],
#        [ 0.67119885,  1.32751945,  1.        ],
#        [ 0.94671323,  1.2138849 ,  1.        ],
#        [ 1.05699935,  0.77746518,  1.        ],
#        [ 0.84389699,  0.87677311,  1.        ],
#        [ 1.05963654,  0.88135664,  1.        ],
#        [ 1.15696045,  0.84456605,  1.        ],
#        [ 0.81705023,  1.18579696,  1.        ],
#        [ 1.57524365,  0.83236301,  1.        ],
#        [ 1.53764803,  1.29187152,  1.        ],
#        [ 0.90294012,  0.93790208,  1.        ],
#        [ 1.25859655,  1.03734673,  1.        ],
# ...

# %%
w1,w2,b,alpha = np.random.normal(0,0.1,4)
alpha = math.fabs(alpha)
temp = np.ones((200,1))
epoch=0
error = []

# %%
while(epoch < 500):
    
    for i in range(200):
        net = w1*data[i,0]+w2*data[i,1]+b
        w1 += alpha*(data[i,2]-net)*data[i,0]
        w2 += alpha*(data[i,2]-net)*data[i,1]
        b += alpha*(data[i,2]-net)
        
    for i in range(200):
        temp[i] = math.fabs(w1*data[i,0]+w2*data[i,1]+b-data[i,2])**2*0.5
        
    error.append(temp.sum()/200)
        
    epoch += 1

# %%
x = np.linspace(-2,2,3)
y = -(w1*x+b)/w2
plt.plot(x,y,'k')
x1 = data[:100,0]
y1 = data[:100,1]
x2 = data[100:,0]
y2 = data[100:,1]
plt.scatter(x1,y1)
plt.scatter(x2,y2)
plt.grid()
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.figure()
plt.plot(error)
plt.xlabel('number of steps')
plt.ylabel('0.5*(t-net)^2')
# Out:
# Text(0, 0.5, '0.5*(t-net)^2')
